# %%
num = int(input("Enter a number: "))
print(type(num))
# Out:
# <class 'int'>

# %%
num
# Out:
# 12

# %%
if num%2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
num%2 == 0
# Out:
# True

# %%
input_json = {
    "name": "data.csv",
    "table_name": "user_data"
}

# %%
#Layer - All possible input values (optional + required fields)
input_json = {
    "name": "data.csv",
    "table_name": "user_data",
    "mergeSchema": None
}

# %%
if input_json["mergeSchema"] or input_json["mergeSchema"] is None:
    print("merging the schema")
else:
    print("Skipping the new column")
# Out:
# merging the schema

# %%
nums = [1,2,3,4,5]

if num in nums:
    print("It is present")
elif num not in nums and num%2==0:
    nums.append(num)
    print("Adding number entered by user")
    print(nums)
else:
    print("Maneg Nadi")
# Out:
# Adding number entered by user
# [1, 2, 3, 4, 5, 12]

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 12]

# %% [markdown]
# Membership operators
# is None = To check if a certain value is member of NoneType
# in = to check membership of a certain value in an iterable (sequential datatypes)
# not in = to check if a certain value is not a member of an iterable
