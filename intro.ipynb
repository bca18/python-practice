# %%
print("Hello World")
# Out:
# Hello World

# %%
1+2
# Out:
# 3

# %%
a = 3

# %%
a
# Out:
# 3

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
class Karthik:
    name = "Karthik"

# %%
k = Karthik()

# %%
print(type(k))
# Out:
# <class '__main__.Karthik'>

# %%
if __name__ == "__main__":
    print("This is the main module.")
# Out:
# This is the main module.

# %%
a = 3
print(a)
print(type(a))
# Out:
# 3
# <class 'int'>

# %%
b = 3.5
print(b)
print(type(b))
# Out:
# 3.5
# <class 'float'>

# %%
c = "Karthik"
print(c)
print(type(c))
# Out:
# Karthik
# <class 'str'>

# %%
d = True
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
e = "3"
print(e)
print(type(e))
# Out:
# 3
# <class 'str'>

# %%
e = int(e)
print(e)
print(type(e))
# Out:
# 3
# <class 'int'>

# %%
f = "3.5"  
print(f)
print(type(f))
# Out:
# 3.5
# <class 'str'>

# %%
f = float(f)
print(f)
print(type(f))
# Out:
# 3.5
# <class 'float'>

# %%
f = int(f)
print(f)    
print(type(f))
# Out:
# 3
# <class 'int'>

# %%
a = 3
b = 2
print(a + b)
# Out:
# 5

# %%
print(a-b)
# Out:
# 1

# %%
print(a*b)
# Out:
# 6

# %%
print(a/b)
# Out:
# 1.5

# %%
print(a//b)
# Out:
# 1

# %%
print(a%b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 9

# %%
print(a | b)
# Out:
# 3

# %%
print(a  &b)
# Out:
# 2

# %%
print(a ^ b)
# Out:
# 1

# %%
print(~1)
# Out:
# -2

# %%
a = True 
b = False

# %%
print(a and b)
# Out:
# False

# %%
print(a or b)
# Out:
# True

# %%
# Complex Datatypes

# %%
#list, strings

name = "Karthik"

arr = [1,'2',3.5,True]

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(arr))
# Out:
# <class 'list'>

# %%
print(arr)
# Out:
# [1, '2', 3.5, True]

# %%
# int arr = {1,2,3,4}

# %%
# tuples, sets, dictionaries

# %%
def sum():
    c=3
    print(c)

c = sum()

print(c)
# Out:
# 3
# None
